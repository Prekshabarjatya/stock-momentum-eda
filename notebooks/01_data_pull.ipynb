# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [raw]
# df = yf.download("RELIANCE.NS", start = "2024-01-01", end = "2025-01-01")
#
# print("Shape:", df.shape)
# print("\nFirst 5 rows:")
# df.head()

# %%
tickers = [
    "RELIANCE.NS",
    "TCS.NS",
    "HDFCBANK.NS",
    "INFY.NS",
    "ICICIBANK.NS"
]

data = yf.download(tickers, start = "2020-01-01", end = "2025-01-01")

close_prices = data["Close"]

print("Shape:", close_prices.shape)
close_prices.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
# Shape: (1238, 5)
# Ticker      HDFCBANK.NS  ICICIBANK.NS     INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2020-01-01   605.529358    519.138000  633.151123   672.216187  1841.150024
# 2020-01-02   609.389160    522.861572  631.303772   683.660278  1832.698242
# 2020-01-03   600.698792    521.169006  641.013367   684.484070  1869.221680
# 2020-01-06   587.698853    508.450562  634.869568   668.609314  1869.052002
# 2020-01-07   597.004822    505.742371  625.460693   678.895630  1873.639038

# %%
close_prices.to_csv("../data/close_prices.csv")
print("Data saved successfully!")
# Out:
# Data saved successfully!

# %%
close_prices.plot(figsize=(12,6), title = "NIFTY 50 - Closing Prices (2020-2025)")

plt.xlabel("Data")
plt.ylabel("Price (INR)")
plt.legend()
plt.tight_layout()
plt.savefig("../data/close_prices.png")
plt.show()

print("Chart Saved")
# Out:
# Chart Saved
